# %% [markdown]
# https://www.linkedin.com/in/nicolas-daniel-hernandez-venegas-346b64222/recent-activity/

# %% [markdown]
# ![imagen_2023-03-06_023931421.png](data:image/png;base64,...)

# %% [markdown]
# CERTIFICADOS
#
# *   https://courses.cognitiveclass.ai/certificates/129bd38371134d2a91b6ab71f671afd4
# *   https://courses.cognitiveclass.ai/certificates/fef6d6c3984c4d3aaa25f9481f8cdd0d
# *   https://courses.cognitiveclass.ai/certificates/00172d882c184b17991fe59d15edc51c
